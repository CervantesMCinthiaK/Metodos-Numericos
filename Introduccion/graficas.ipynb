# %% [markdown]
# # Gráfica de $f(x)=x - 3^{-x}$

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def g(x):
    return x

def h(x):
    return -3**(-x)

# Función cuadrática.
def f(x):
    return x - 3**(-x)

# %%
# Valores del eje X que toma el gráfico.
x=np.linspace(-5, 5,100)

# %%
# Graficar ambas funciones
plt.figure(figsize=(12, 8))
plt.title("Gráfica de $f(x)=x-3**(-x)$")
# Agregar rótulos a los ejes
plt.xlabel('Eje X')
plt.ylabel('Eje Y')

# Agregar retícula
plt.grid(True)


plt.plot(x,g(x))
plt.plot(x,h(x))
plt.plot(x,f(x))
plt.axhline(0, color="blue")
plt.axvline(0, color="black")
plt.xlim(-5, 5)
plt.ylim(-5, 5)
plt.savefig("output.png") # Guardar gráfico como imágen PNG.
plt.grid(color="pink")
# Mostrarlo.
plt.show()

# %% [markdown]
# Ejercicio 1: Graficar las funciones $x$ y $3^{-x}$ en una sola figura y comentar cómo su resta da origen a la gráfica de $f(x)$.
#
# Ejercicio 2: Agregar título, color, retícula, rótulos a los ejes y aumentar el tamaño de la gráfica.

# %% [markdown]
# Aquí vemos cómo $f(x)=x-3^{x}$ resulta de sumar
# $f(x)=g(x) + h(x)$, es decir
#  $f(x)= x + (-3^{-x})$
