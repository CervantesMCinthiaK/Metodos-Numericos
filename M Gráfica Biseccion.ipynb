# %% [markdown]
# <a href="https://colab.research.google.com/github/CervantesMCinthiaK/Metodos-Numericos/blob/main/M%20Gr%C3%A1fica%20Biseccion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Método de bisección

# %%
from math import *
import numpy as np
import matplotlib . pyplot as plt

# %%
def funcion1(x):
    return x-2**(-x)

# %%
# Valores del eje X que toma el gráfico.
x=np.linspace (0,5,100)

# %%
# Graficar las funciones.
plt.figure(figsize=(12, 8))
plt.title("Gráficas")
# Agregar rótulos a los ejes
plt.xlabel('Eje X')
plt.ylabel('Eje Y')

# Agregar retícula
plt.grid(True)

plt.plot(x, funcion1(x))

plt.axhline(0, color="black")
plt.axvline(0, color="black")
plt.savefig("output.png") # Guardar gráfico como imágen PNG.
# Mostrarlo.
plt.show()

# %%
#Evaluar la funcion en 0 y 1
f1=funcion1(0)
print(f1)
f2=funcion1(1)
print(f2)
# Out:
# -1
# 0.5

# %%
# Ingreso datos de entrada para los diferentes métodos a trabajar
a = 0
b = 1

# guarda valores iniciales
a0 = a
b0 = b

#guarda valores iniciales del error y del número de iteraciones
tol = 0.000001 #float(input("Ingrese el valor de la tolerancia: "))
nmax = 100 #float(input("Ingrese el número máximo de iteraciones: "))
error = 100
niter = 1

# %%
# Método de Bisección

# evaluo primer valor medio
m = a + (b - a)/2

#Evaluacion de la función en los puntos a, b y m
fa = funcion1(a)
fb = funcion1(b)
fm = funcion1(m)

print("# iter\t\t a \t\t f(a) \t\t b \t\t f(b) \t\t m \t\t f(m) \t\t error")
print("{0} \t\t {1:6.4f} \t {2:6.4f} \t {3:6.4f} \t {4:6.4f} \t {5:6.4f} \t {6:6.4f} \t {7:6.4f}".format(niter, a0, fa, b0, fb, m, fm, error ))

# ciclo iterativo
errores=[] #crear espacio un arreglo
#errores1=[]
while error > tol and niter < nmax:
    m = a + (b - a) / 2
    # Almacena el último m
    m_last = m
    if np.sign(fa) == np.sign(fm):
        a = m
        fa = funcion1(a)
    else:
        b = m
        fb = funcion1(b)

    m = a + (b - a)/2
    fm = funcion1(m)
    error = abs(m - m_last) # Calcula el error como la diferencia de m
    c=error/0.50
    errores.append(c) #ir guardando

    #errores1.append(error/errores[0])
    niter += 1
    print("{0} \t\t {1:6.6f} \t {2:6.6f} \t {3:6.6f} \t {4:6.6f} \t {5:6.6f} \t {6:6.6f} \t {7:6.6f}".format(niter, a, fa, b, fb, m, fm, error ))

print("La raíz de la función dada en el intervalo [{0:6.4f},{1:6.4f}] es {2:6.6f}".format(a0,b0,m))
# Out:
# # iter		 a 		 f(a) 		 b 		 f(b) 		 m 		 f(m) 		 error
# 1 		 0.0000 	 -1.0000 	 1.0000 	 0.5000 	 0.5000 	 -0.2071 	 100.0000
# 2 		 0.500000 	 -0.207107 	 1.000000 	 0.500000 	 0.750000 	 0.155396 	 0.250000
# 3 		 0.500000 	 -0.207107 	 0.750000 	 0.155396 	 0.625000 	 -0.023420 	 0.125000
# 4 		 0.625000 	 -0.023420 	 0.750000 	 0.155396 	 0.687500 	 0.066571 	 0.062500
# 5 		 0.625000 	 -0.023420 	 0.687500 	 0.066571 	 0.656250 	 0.021725 	 0.031250
# 6 		 0.625000 	 -0.023420 	 0.656250 	 0.021725 	 0.640625 	 -0.000810 	 0.015625
# 7 		 0.640625 	 -0.000810 	 0.656250 	 0.021725 	 0.648438 	 0.010467 	 0.007812
# 8 		 0.640625 	 -0.000810 	 0.648438 	 0.010467 	 0.644531 	 0.004831 	 0.003906
# 9 		 0.640625 	 -0.000810 	 0.644531 	 0.004831 	 0.642578 	 0.002011 	 0.001953
# 10 		 0.640625 	 -0.000810 	 0.642578 	 0.002011 	 0.641602 	 0.000601 	 0.000977
# 11 		 0.640625 	 -0.000810 	 0.641602 	 0.000601 	 0.641113 	 -0.000105 	 0.000488
# ...

# %% [markdown]
# Aquí empieza a gráficar el error modificando el código 30/septiembre

# %%
print(errores) #estamos imprimiendo errores
# Out:
# [0.5, 0.25, 0.125, 0.0625, 0.03125, 0.015625, 0.0078125, 0.00390625, 0.001953125, 0.0009765625, 0.00048828125, 0.000244140625, 0.0001220703125, 6.103515625e-05, 3.0517578125e-05, 1.52587890625e-05, 7.62939453125e-06, 3.814697265625e-06, 1.9073486328125e-06]

# %%
# Graficar las funciones.
plt.figure(figsize=(12, 8))
plt.title("Gráfica de los errores")
# Agregar rótulos a los ejes
plt.xlabel("Iteraciones")
plt.ylabel("Errores")

# Agregar retícula
plt.grid(True)

plt.plot(errores, label=r"$errores$")
#plt.plot(errores1, label=r"$errores1$")

plt.axhline(0, color="pink")
plt.axvline(0, color="black")
plt.savefig("output.png") # Guardar gráfico como imágen PNG.

# Mostrarlo.
plt.legend()
plt.show()

# %% [markdown]
# Use el Método de bisección soluciones precisas dentro de $10^{-5}$ para $f(x)=x-2^{-x}$
